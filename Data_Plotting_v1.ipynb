# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt

# Replace '../Folder1/your_file.csv' with the actual path to your CSV file
data = pd.read_csv('Data_Files/owid-covid-data.csv')

# Display the first few rows of the DataFrame
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336078 entries, 0 to 336077
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    336078 non-null  object
#  1   continent                                   320099 non-null  object
#  2   location                                    336078 non-null  object
#  3   date                                        336078 non-null  object
#  4   total_cases                                 298424 non-null  float64
#  5   new_cases                                   326839 non-null  float64
#  6   new_cases_smoothed                          325576 non-null  float64
#  7   total_deaths                                277172 non-null  float64
#  8   new_deaths                                  326894 non-null  float64
#  9   new_deaths_smoothed                         325664 non-null  float64
#  10  total_cases_per_million                     298424 non-null  float64
#  11  new_cases_per_million                       326839 non-null  float64
#  12  new_cases_smoothed_per_million              325576 non-null  float64
#  13  total_deaths_per_million                    277172 non-null  float64
#  14  new_deaths_per_million                      326894 non-null  float64
#  15  new_deaths_smoothed_per_million             325664 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                37235 non-null   float64
#  18  icu_patients_per_million                    37235 non-null   float64
#  19  hosp_patients                               38295 non-null   float64
#  20  hosp_patients_per_million                   38295 non-null   float64
#  21  weekly_icu_admissions                       10002 non-null   float64
#  22  weekly_icu_admissions_per_million           10002 non-null   float64
#  23  weekly_hosp_admissions                      22826 non-null   float64
#  24  weekly_hosp_admissions_per_million          22826 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          78102 non-null   float64
#  35  people_vaccinated                           74770 non-null   float64
#  36  people_fully_vaccinated                     71353 non-null   float64
#  37  total_boosters                              46446 non-null   float64
#  38  new_vaccinations                            64271 non-null   float64
#  39  new_vaccinations_smoothed                   177074 non-null  float64
#  40  total_vaccinations_per_hundred              78102 non-null   float64
#  41  people_vaccinated_per_hundred               74770 non-null   float64
#  42  people_fully_vaccinated_per_hundred         71353 non-null   float64
#  43  total_boosters_per_hundred                  46446 non-null   float64
#  44  new_vaccinations_smoothed_per_million       177074 non-null  float64
#  45  new_people_vaccinated_smoothed              176828 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  176828 non-null  float64
#  47  stringency_index                            197651 non-null  float64
#  48  population_density                          285221 non-null  float64
#  49  median_age                                  265271 non-null  float64
#  50  aged_65_older                               255983 non-null  float64
#  51  aged_70_older                               262613 non-null  float64
#  52  gdp_per_capita                              259968 non-null  float64
#  53  extreme_poverty                             167494 non-null  float64
#  54  cardiovasc_death_rate                       260519 non-null  float64
#  55  diabetes_prevalence                         273794 non-null  float64
#  56  female_smokers                              195414 non-null  float64
#  57  male_smokers                                192756 non-null  float64
#  58  handwashing_facilities                      127604 non-null  float64
#  59  hospital_beds_per_thousand                  229968 non-null  float64
#  60  life_expectancy                             309128 non-null  float64
#  61  human_development_index                     252529 non-null  float64
#  62  population                                  336078 non-null  float64
#  63  excess_mortality_cumulative_absolute        11656 non-null   float64
#  64  excess_mortality_cumulative                 11656 non-null   float64
#  65  excess_mortality                            11656 non-null   float64
#  66  excess_mortality_cumulative_per_million     11656 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 171.8+ MB

# %%
# Assume 'data' is your DataFrame
covid19_data = data[['location', 'date', 'total_cases',
                        'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million',
                         'icu_patients_per_million', 'hosp_patients_per_million', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
                         'total_boosters_per_hundred', 'population_density', 'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'female_smokers', 'male_smokers', 'human_development_index',
                         'population'
                        ]]

covid19_data.head()
# Out:
#       location        date  total_cases  new_cases  total_deaths  new_deaths  \
# 0  Afghanistan  2020-01-03          NaN        0.0           NaN         0.0
# 1  Afghanistan  2020-01-04          NaN        0.0           NaN         0.0
# 2  Afghanistan  2020-01-05          NaN        0.0           NaN         0.0
# 3  Afghanistan  2020-01-06          NaN        0.0           NaN         0.0
# 4  Afghanistan  2020-01-07          NaN        0.0           NaN         0.0
#
#    total_cases_per_million  new_cases_per_million  total_deaths_per_million  \
# 0                      NaN                    0.0                       NaN
# 1                      NaN                    0.0                       NaN
# 2                      NaN                    0.0                       NaN
# 3                      NaN                    0.0                       NaN
# 4                      NaN                    0.0                       NaN
#
#    new_deaths_per_million  ...  total_boosters_per_hundred  \
# 0                     0.0  ...                         NaN
# 1                     0.0  ...                         NaN
# 2                     0.0  ...                         NaN
# 3                     0.0  ...                         NaN
# 4                     0.0  ...                         NaN
#
#    population_density  median_age  aged_65_older  aged_70_older  \
# 0              54.422        18.6          2.581          1.337
# 1              54.422        18.6          2.581          1.337
# 2              54.422        18.6          2.581          1.337
# 3              54.422        18.6          2.581          1.337
# 4              54.422        18.6          2.581          1.337
#
#    gdp_per_capita  female_smokers  male_smokers  human_development_index  \
# 0        1803.987             NaN           NaN                    0.511
# 1        1803.987             NaN           NaN                    0.511
# 2        1803.987             NaN           NaN                    0.511
# 3        1803.987             NaN           NaN                    0.511
# 4        1803.987             NaN           NaN                    0.511
#
#    population
# 0  41128772.0
# 1  41128772.0
# 2  41128772.0
# 3  41128772.0
# 4  41128772.0
#
# [5 rows x 25 columns]

# %%
covid19_data
# Out:
#            location        date  total_cases  new_cases  total_deaths  \
# 0       Afghanistan  2020-01-03          NaN        0.0           NaN
# 1       Afghanistan  2020-01-04          NaN        0.0           NaN
# 2       Afghanistan  2020-01-05          NaN        0.0           NaN
# 3       Afghanistan  2020-01-06          NaN        0.0           NaN
# 4       Afghanistan  2020-01-07          NaN        0.0           NaN
# ...             ...         ...          ...        ...           ...
# 336073     Zimbabwe  2023-08-19     265716.0        0.0        5713.0
# 336074     Zimbabwe  2023-08-20     265716.0        0.0        5713.0
# 336075     Zimbabwe  2023-08-21     265716.0        0.0        5713.0
# 336076     Zimbabwe  2023-08-22     265716.0        0.0        5713.0
# 336077     Zimbabwe  2023-08-23     265716.0        0.0        5713.0
#
#         new_deaths  total_cases_per_million  new_cases_per_million  \
# 0              0.0                      NaN                    0.0
# 1              0.0                      NaN                    0.0
# 2              0.0                      NaN                    0.0
# 3              0.0                      NaN                    0.0
# 4              0.0                      NaN                    0.0
# ...            ...                      ...                    ...
# 336073         0.0                 16281.08                    0.0
# 336074         0.0                 16281.08                    0.0
# 336075         0.0                 16281.08                    0.0
# 336076         0.0                 16281.08                    0.0
# 336077         0.0                 16281.08                    0.0
#
#         total_deaths_per_million  new_deaths_per_million  ...  \
# 0                            NaN                     0.0  ...
# 1                            NaN                     0.0  ...
# 2                            NaN                     0.0  ...
# 3                            NaN                     0.0  ...
# 4                            NaN                     0.0  ...
# ...                          ...                     ...  ...
# 336073                    350.05                     0.0  ...
# 336074                    350.05                     0.0  ...
# 336075                    350.05                     0.0  ...
# 336076                    350.05                     0.0  ...
# 336077                    350.05                     0.0  ...
#
#         total_boosters_per_hundred  population_density  median_age  \
# 0                              NaN              54.422        18.6
# 1                              NaN              54.422        18.6
# 2                              NaN              54.422        18.6
# 3                              NaN              54.422        18.6
# 4                              NaN              54.422        18.6
# ...                            ...                 ...         ...
# 336073                         NaN              42.729        19.6
# 336074                         NaN              42.729        19.6
# 336075                         NaN              42.729        19.6
# 336076                         NaN              42.729        19.6
# 336077                         NaN              42.729        19.6
#
#         aged_65_older  aged_70_older  gdp_per_capita  female_smokers  \
# 0               2.581          1.337        1803.987             NaN
# 1               2.581          1.337        1803.987             NaN
# 2               2.581          1.337        1803.987             NaN
# 3               2.581          1.337        1803.987             NaN
# 4               2.581          1.337        1803.987             NaN
# ...               ...            ...             ...             ...
# 336073          2.822          1.882        1899.775             1.6
# 336074          2.822          1.882        1899.775             1.6
# 336075          2.822          1.882        1899.775             1.6
# 336076          2.822          1.882        1899.775             1.6
# 336077          2.822          1.882        1899.775             1.6
#
#         male_smokers  human_development_index  population
# 0                NaN                    0.511  41128772.0
# 1                NaN                    0.511  41128772.0
# 2                NaN                    0.511  41128772.0
# 3                NaN                    0.511  41128772.0
# 4                NaN                    0.511  41128772.0
# ...              ...                      ...         ...
# 336073          30.7                    0.571  16320539.0
# 336074          30.7                    0.571  16320539.0
# 336075          30.7                    0.571  16320539.0
# 336076          30.7                    0.571  16320539.0
# 336077          30.7                    0.571  16320539.0
#
# [336078 rows x 25 columns]

# %%
# Rename the columns using the .rename() method
new_column_names = {
    'location': 'Location',
    'date': 'Date',
    'total_cases': 'totalCases',
    'new_cases': 'newCases',
    'total_deaths': 'totalDeaths',
    'new_deaths': 'newDeaths',
    'total_cases_per_million': 'totalCasesPerMillion',
    'new_cases_per_million': 'newCasesPerMillion',
    'total_deaths_per_million': 'totalDeathsPerMillion',
    'new_deaths_per_million': 'newDeathsPerMillion',
    'icu_patients_per_million': 'icuPatientsPerMillion',
    'hosp_patients_per_million': 'hospitalPatientsPerMillion',
    'total_vaccinations_per_hundred': 'totalVaccinationsPerHundred',
    'people_vaccinated_per_hundred': 'peopleVaccinatedPerHundred',
    'people_fully_vaccinated_per_hundred': 'peopleFullyVaccinatedPerHundred',
    'total_boosters_per_hundred': 'totalBoostersPerHundred',
    'population_density': 'populationDensity',
    'median_age': 'medianAge',
    'aged_65_older': 'aged65Older',
    'aged_70_older': 'aged70Older',
    'gdp_per_capita': 'gdpPerCapita',
    'female_smokers': 'femaleSmokers',
    'male_smokers': 'maleSmokers',
    'human_development_index': 'humanDevelopmentIndex',
    'population': 'Population'
}

covid19_data = covid19_data.rename(columns=new_column_names)
covid19_data.head()
# Out:
#       Location        Date  totalCases  newCases  totalDeaths  newDeaths  \
# 0  Afghanistan  2020-01-03         NaN       0.0          NaN        0.0
# 1  Afghanistan  2020-01-04         NaN       0.0          NaN        0.0
# 2  Afghanistan  2020-01-05         NaN       0.0          NaN        0.0
# 3  Afghanistan  2020-01-06         NaN       0.0          NaN        0.0
# 4  Afghanistan  2020-01-07         NaN       0.0          NaN        0.0
#
#    totalCasesPerMillion  newCasesPerMillion  totalDeathsPerMillion  \
# 0                   NaN                 0.0                    NaN
# 1                   NaN                 0.0                    NaN
# 2                   NaN                 0.0                    NaN
# 3                   NaN                 0.0                    NaN
# 4                   NaN                 0.0                    NaN
#
#    newDeathsPerMillion  ...  totalBoostersPerHundred  populationDensity  \
# 0                  0.0  ...                      NaN             54.422
# 1                  0.0  ...                      NaN             54.422
# 2                  0.0  ...                      NaN             54.422
# 3                  0.0  ...                      NaN             54.422
# 4                  0.0  ...                      NaN             54.422
#
#    medianAge  aged65Older  aged70Older  gdpPerCapita  femaleSmokers  \
# 0       18.6        2.581        1.337      1803.987            NaN
# 1       18.6        2.581        1.337      1803.987            NaN
# 2       18.6        2.581        1.337      1803.987            NaN
# 3       18.6        2.581        1.337      1803.987            NaN
# 4       18.6        2.581        1.337      1803.987            NaN
#
#    maleSmokers  humanDevelopmentIndex  Population
# 0          NaN                  0.511  41128772.0
# 1          NaN                  0.511  41128772.0
# 2          NaN                  0.511  41128772.0
# 3          NaN                  0.511  41128772.0
# 4          NaN                  0.511  41128772.0
#
# [5 rows x 25 columns]

# %%
covid19_data['Date'] = pd.to_datetime(covid19_data['Date'])
covid19_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336078 entries, 0 to 336077
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Location                         336078 non-null  object
#  1   Date                             336078 non-null  datetime64[ns]
#  2   totalCases                       298424 non-null  float64
#  3   newCases                         326839 non-null  float64
#  4   totalDeaths                      277172 non-null  float64
#  5   newDeaths                        326894 non-null  float64
#  6   totalCasesPerMillion             298424 non-null  float64
#  7   newCasesPerMillion               326839 non-null  float64
#  8   totalDeathsPerMillion            277172 non-null  float64
#  9   newDeathsPerMillion              326894 non-null  float64
#  10  icuPatientsPerMillion            37235 non-null   float64
#  11  hospitalPatientsPerMillion       38295 non-null   float64
#  12  totalVaccinationsPerHundred      78102 non-null   float64
#  13  peopleVaccinatedPerHundred       74770 non-null   float64
#  14  peopleFullyVaccinatedPerHundred  71353 non-null   float64
#  15  totalBoostersPerHundred          46446 non-null   float64
#  16  populationDensity                285221 non-null  float64
#  17  medianAge                        265271 non-null  float64
#  18  aged65Older                      255983 non-null  float64
#  19  aged70Older                      262613 non-null  float64
#  20  gdpPerCapita                     259968 non-null  float64
#  21  femaleSmokers                    195414 non-null  float64
#  22  maleSmokers                      192756 non-null  float64
#  23  humanDevelopmentIndex            252529 non-null  float64
#  24  Population                       336078 non-null  float64
# dtypes: datetime64[ns](1), float64(23), object(1)
# memory usage: 64.1+ MB

# %%
def process_covid19_data(covid19_data, country):
    # Apply filter for rows where 'location' is in the list_of_countries
    filtered_covid19_data = covid19_data[covid19_data['Location'].isin(country)]
    
    # Group by 'date' column and aggregate the specified columns
    grouped = filtered_covid19_data.groupby(filtered_covid19_data['Date'].dt.strftime('%Y-%m')).agg({
        'totalCases': 'sum',
        'newCases': 'sum',
        'totalDeaths': 'sum',
        'newDeaths': 'sum',
        'totalCasesPerMillion': 'sum',
        'newCasesPerMillion': 'sum',
        'totalDeathsPerMillion': 'sum',
        'newDeathsPerMillion': 'sum',
        'icuPatientsPerMillion': 'sum',
        'hospitalPatientsPerMillion': 'sum',
        'totalVaccinationsPerHundred': 'sum',
        'peopleVaccinatedPerHundred': 'sum',
        'peopleFullyVaccinatedPerHundred': 'sum',
        'totalBoostersPerHundred': 'sum',
        'populationDensity': 'mean',
        'medianAge': 'mean',
        'aged65Older': 'sum',
        'aged70Older': 'sum',
        'gdpPerCapita': 'mean',
        'femaleSmokers': 'sum',
        'maleSmokers': 'sum',
        'humanDevelopmentIndex': 'mean',
        'Population': 'mean'
    })
    
    # Move the index to a new column ('Month-Year')
    grouped.reset_index(drop=False, inplace=True)
    
    return grouped

# Assuming you have a DataFrame named 'covid19_data'
# and a list of countries you want to filter by
country = ['Australia']  # Note the use of square brackets to define a list

# to create a filtered data for another country dataframe, just change Australia to Zimbabwe for example
# in the country = ['Zimbabwe']
# Zimbabwe_grouped_data = process_covid19_data(covid19_data, country)
# Zimbabwe_grouped_data.head()
Australia_grouped_data = process_covid19_data(covid19_data, country)
Australia_grouped_data.head()
# Out:
#       Date  totalCases  newCases  totalDeaths  newDeaths  \
# 0  2020-01        35.0       9.0          0.0        0.0
# 1  2020-02       478.0      16.0          0.0        0.0
# 2  2020-03     31988.0    4334.0        231.0       21.0
# 3  2020-04    186937.0    2387.0       1895.0       74.0
# 4  2020-05    216814.0     439.0       3204.0       12.0
#
#    totalCasesPerMillion  newCasesPerMillion  totalDeathsPerMillion  \
# 0                 1.337               0.343                  0.000
# 1                18.259               0.610                  0.000
# 2              1221.969             165.562                  8.824
# 3              7141.157              91.184                 72.391
# 4              8282.483              16.769                122.391
#
#    newDeathsPerMillion  icuPatientsPerMillion  ...  totalBoostersPerHundred  \
# 0                0.000                  0.000  ...                      0.0
# 1                0.000                  0.000  ...                      0.0
# 2                0.800                  3.132  ...                      0.0
# 3                2.824                 73.689  ...                      0.0
# 4                0.457                 16.349  ...                      0.0
#
#    populationDensity  medianAge  aged65Older  aged70Older  gdpPerCapita  \
# 0              3.202       37.9      449.616      293.741      44648.71
# 1              3.202       37.9      449.616      293.741      44648.71
# 2              3.202       37.9      480.624      313.999      44648.71
# 3              3.202       37.9      465.120      303.870      44648.71
# 4              3.202       37.9      480.624      313.999      44648.71
#
#    femaleSmokers  maleSmokers  humanDevelopmentIndex  Population
# 0          377.0        478.5                  0.944  26177410.0
# 1          377.0        478.5                  0.944  26177410.0
# 2          403.0        511.5                  0.944  26177410.0
# 3          390.0        495.0                  0.944  26177410.0
# 4          403.0        511.5                  0.944  26177410.0
#
# [5 rows x 24 columns]

# %%
# Export the DataFrame to a CSV file
Australia_grouped_data.to_csv('Australia_grouped_data.csv', index=True)

# %%
Australia_grouped_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             44 non-null     object
#  1   totalCases                       44 non-null     float64
#  2   newCases                         44 non-null     float64
#  3   totalDeaths                      44 non-null     float64
#  4   newDeaths                        44 non-null     float64
#  5   totalCasesPerMillion             44 non-null     float64
#  6   newCasesPerMillion               44 non-null     float64
#  7   totalDeathsPerMillion            44 non-null     float64
#  8   newDeathsPerMillion              44 non-null     float64
#  9   icuPatientsPerMillion            44 non-null     float64
#  10  hospitalPatientsPerMillion       44 non-null     float64
#  11  totalVaccinationsPerHundred      44 non-null     float64
#  12  peopleVaccinatedPerHundred       44 non-null     float64
#  13  peopleFullyVaccinatedPerHundred  44 non-null     float64
#  14  totalBoostersPerHundred          44 non-null     float64
#  15  populationDensity                44 non-null     float64
#  16  medianAge                        44 non-null     float64
#  17  aged65Older                      44 non-null     float64
#  18  aged70Older                      44 non-null     float64
#  19  gdpPerCapita                     44 non-null     float64
#  20  femaleSmokers                    44 non-null     float64
#  21  maleSmokers                      44 non-null     float64
#  22  humanDevelopmentIndex            44 non-null     float64
#  23  Population                       44 non-null     float64
# dtypes: float64(23), object(1)
# memory usage: 8.4+ KB

# %%
## How to add the Column GDPNew and PopulationNew to the dataframe

# %%
# Function to map year to population
def map_year_to_population(date_str):
    year = int(date_str.split('-')[0])
    if year == 2020:
        return 25655289
    elif year == 2021:
        return 25688079
    elif year == 2022:
        return 25978935
    else:
        return None  # You can specify a default value or handle other cases as needed

# Apply the mapping function to create a new "Population" column
Australia_grouped_data['Population'] = Australia_grouped_data['Date'].apply(map_year_to_population)

# Display the DataFrame
Australia_grouped_data.head()
# Out:
#       Date  totalCases  newCases  totalDeaths  newDeaths  \
# 0  2020-01        35.0       9.0          0.0        0.0
# 1  2020-02       478.0      16.0          0.0        0.0
# 2  2020-03     31988.0    4334.0        231.0       21.0
# 3  2020-04    186937.0    2387.0       1895.0       74.0
# 4  2020-05    216814.0     439.0       3204.0       12.0
#
#    totalCasesPerMillion  newCasesPerMillion  totalDeathsPerMillion  \
# 0                 1.337               0.343                  0.000
# 1                18.259               0.610                  0.000
# 2              1221.969             165.562                  8.824
# 3              7141.157              91.184                 72.391
# 4              8282.483              16.769                122.391
#
#    newDeathsPerMillion  icuPatientsPerMillion  ...  totalBoostersPerHundred  \
# 0                0.000                  0.000  ...                      0.0
# 1                0.000                  0.000  ...                      0.0
# 2                0.800                  3.132  ...                      0.0
# 3                2.824                 73.689  ...                      0.0
# 4                0.457                 16.349  ...                      0.0
#
#    populationDensity  medianAge  aged65Older  aged70Older  gdpPerCapita  \
# 0              3.202       37.9      449.616      293.741      44648.71
# 1              3.202       37.9      449.616      293.741      44648.71
# 2              3.202       37.9      480.624      313.999      44648.71
# 3              3.202       37.9      465.120      303.870      44648.71
# 4              3.202       37.9      480.624      313.999      44648.71
#
#    femaleSmokers  maleSmokers  humanDevelopmentIndex  Population
# 0          377.0        478.5                  0.944  25655289.0
# 1          377.0        478.5                  0.944  25655289.0
# 2          403.0        511.5                  0.944  25655289.0
# 3          390.0        495.0                  0.944  25655289.0
# 4          403.0        511.5                  0.944  25655289.0
#
# [5 rows x 24 columns]

# %%
# Function to map year to population
def map_value_to_gdp(date_str):
    year = int(date_str.split('-')[0])
    if year == 2020:
        return 1326944627876.87
    elif year == 2021:
        return 1552703151616.01
    elif year == 2022:
        return 1675418665067.09
    else:
        return None  # You can specify a default value or handle other cases as needed

# Apply the mapping function to create a new "Population" column
Australia_grouped_data['gDPNew'] = Australia_grouped_data['Date'].apply(map_value_to_gdp)

# Display the DataFrame
Australia_grouped_data.head()
# Out:
#       Date  totalCases  newCases  totalDeaths  newDeaths  \
# 0  2020-01        35.0       9.0          0.0        0.0
# 1  2020-02       478.0      16.0          0.0        0.0
# 2  2020-03     31988.0    4334.0        231.0       21.0
# 3  2020-04    186937.0    2387.0       1895.0       74.0
# 4  2020-05    216814.0     439.0       3204.0       12.0
#
#    totalCasesPerMillion  newCasesPerMillion  totalDeathsPerMillion  \
# 0                 1.337               0.343                  0.000
# 1                18.259               0.610                  0.000
# 2              1221.969             165.562                  8.824
# 3              7141.157              91.184                 72.391
# 4              8282.483              16.769                122.391
#
#    newDeathsPerMillion  icuPatientsPerMillion  ...  populationDensity  \
# 0                0.000                  0.000  ...              3.202
# 1                0.000                  0.000  ...              3.202
# 2                0.800                  3.132  ...              3.202
# 3                2.824                 73.689  ...              3.202
# 4                0.457                 16.349  ...              3.202
#
#    medianAge  aged65Older  aged70Older  gdpPerCapita  femaleSmokers  \
# 0       37.9      449.616      293.741      44648.71          377.0
# 1       37.9      449.616      293.741      44648.71          377.0
# 2       37.9      480.624      313.999      44648.71          403.0
# 3       37.9      465.120      303.870      44648.71          390.0
# 4       37.9      480.624      313.999      44648.71          403.0
#
#    maleSmokers  humanDevelopmentIndex  Population        gDPNew
# 0        478.5                  0.944  25655289.0  1.326945e+12
# 1        478.5                  0.944  25655289.0  1.326945e+12
# 2        511.5                  0.944  25655289.0  1.326945e+12
# 3        495.0                  0.944  25655289.0  1.326945e+12
# 4        511.5                  0.944  25655289.0  1.326945e+12
#
# [5 rows x 25 columns]

# %%
[{'Year': '2020', 'GDP': 1326944627876.87},
 {'Year': '2021', 'GDP': 1552703151616.01},
 {'Year': '2022', 'GDP': 1675418665067.09}]

# %%
[{'Date': '2020', 'Population Total': 25655289},
 {'Date': '2021', 'Population Total': 25688079},
 {'Date': '2022', 'Population Total': 25978935}]

# %%
# Assuming you have a DataFrame named 'df' with the relevant columns
# Convert the 'Date' column to datetime if it's not already in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')

# Create a line plot of 'totalCases' over time
plt.figure(figsize=(12, 6))

plt.plot(df['Date'], df['totalCases'], label='Total Cases', marker='o', linestyle='-')

plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.title('Total Cases Over Time')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Create a line plot of 'newCases' and 'newDeaths' over time
plt.figure(figsize=(12, 6))

plt.plot(df['Date'], df['newCases'], label='New Cases', marker='o', linestyle='-')
plt.plot(df['Date'], df['newDeaths'], label='New Deaths', marker='x', linestyle='-')

plt.xlabel('Date')
plt.ylabel('Count')
plt.title('New Cases and New Deaths Over Time')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Create a figure and axis object
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot 'newCases' on the left y-axis
ax1.plot(df['Date'], df['newCases'], label='New Cases', color='b', marker='o', linestyle='-')
ax1.set_xlabel('Date')
ax1.set_ylabel('New Cases', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a second y-axis on the right side for 'newDeaths'
ax2 = ax1.twinx()
ax2.plot(df['Date'], df['newDeaths'], label='New Deaths', color='r', marker='x', linestyle='-')
ax2.set_ylabel('New Deaths', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Adding legends
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
lines = lines_1 + lines_2
labels = labels_1 + labels_2
ax1.legend(lines, labels, loc='upper left')

plt.title('New Cases and New Deaths Over Time')
plt.grid(True)

plt.show()

# %%
df = Australia_grouped_data.copy()
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')

# Plot the data
plt.figure(figsize=(12, 6))
#plt.scatter(df['Date'], df['totalCases'], c=df['aged65Older'], cmap='Blues', label='aged65Older')
#plt.colorbar(label='aged65Older')
plt.scatter(df['Date'], df['totalCases'], c=df['aged70Older'], cmap='Reds', label='aged70Older', marker='x')
plt.colorbar(label='aged70Older')
plt.xlabel('Month-Year')
plt.ylabel('Total Cases')
plt.title('Total Cases Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the data
plt.figure(figsize=(12, 6))
plt.scatter(df['Date'], df['totalCases'], c=df['aged65Older'], cmap='Blues', label='aged65Older')
plt.colorbar(label='aged65Older')
#plt.scatter(df['Date'], df['totalCases'], c=df['aged70Older'], cmap='Reds', label='aged70Older', marker='x')
#plt.colorbar(label='aged70Older')
plt.xlabel('Month-Year')
plt.ylabel('Total Cases')
plt.title('Total Cases Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
df = Australia_grouped_data.copy()


# Assuming you have a DataFrame named 'df' with columns 'Date', 'totalCases', 'aged65Older', and 'aged70Older'
# Convert the 'Date' column to datetime if it's not already in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')

# Create a scatter plot with two subplots (one for 'age65Older' and one for 'age70Older')
plt.figure(figsize=(12, 6))

# Scatter plot for 'age65Older' on the left side
plt.subplot(1, 2, 1)
plt.scatter(df['Date'], df['totalCases'], c=df['aged65Older'], cmap='Blues', label='aged65Older')
plt.colorbar(label='aged65Older')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.title('Total Cases vs. age65Older')
plt.xticks(rotation=90)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

# Scatter plot for 'age70Older' on the right side
plt.subplot(1, 2, 2)
plt.scatter(df['Date'], df['totalCases'], c=df['aged70Older'], cmap='Reds', label='aged70Older', marker='x')
plt.colorbar(label='aged70Older')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.title('Total Cases vs. age70Older')
plt.xticks(rotation=90)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

plt.tight_layout()  # Ensures that the subplots don't overlap
plt.show()

# %%
# Assuming you have a DataFrame named 'df' with columns 'Date', 'newCases', 'aged65Older', and 'aged70Older'
# Convert the 'Date' column to datetime if it's not already in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')

# Create a scatter plot with two subplots (one for 'age65Older' and one for 'age70Older')
plt.figure(figsize=(12, 6))

# Scatter plot for 'age65Older' on the left side
plt.subplot(1, 2, 1)
plt.scatter(df['Date'], df['newCases'], c=df['aged65Older'], cmap='Blues', label='aged65Older')
plt.colorbar(label='aged65Older')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.title('New Cases vs. age65Older')
plt.xticks(rotation=90)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

# Scatter plot for 'age70Older' on the right side
plt.subplot(1, 2, 2)
plt.scatter(df['Date'], df['newCases'], c=df['aged70Older'], cmap='Reds', label='aged70Older', marker='x')
plt.colorbar(label='aged70Older')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.title('New Cases vs. age70Older')
plt.xticks(rotation=90)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

plt.tight_layout()  # Ensures that the subplots don't overlap
plt.show()

# %%
# Assuming you have a DataFrame named 'df' with columns 'Date', 'newCases', 'aged65Older', and 'aged70Older'
# Convert the 'Date' column to datetime if it's not already in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')

# Create a line plot with two subplots (one for 'age65Older' and one for 'age70Older')
plt.figure(figsize=(12, 6))

# Line plot for 'age65Older' on the left side
plt.subplot(1, 2, 1)
plt.plot(df['Date'], df['newCases'], label='New Cases', color='blue')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.title('New Cases vs. Date')
plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees
plt.grid(True)

# Line plot for 'age70Older' on the right side
plt.subplot(1, 2, 2)
plt.plot(df['Date'], df['aged65Older'], label='aged65Older', color='red')
plt.plot(df['Date'], df['aged70Older'], label='aged70Older', linestyle='--', color='green')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.title('Aged Population vs. Date')
plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees
plt.grid(True)

plt.tight_layout()  # Ensures that the subplots don't overlap
plt.legend()
plt.show()

# %%
# Create a scatter plot with two subplots (one for 'aged65Older' and one for 'aged70Older')
plt.figure(figsize=(12, 6))

# Scatter plot for 'aged65Older' on the left side
plt.subplot(1, 2, 1)
plt.scatter(df['Date'], df['totalDeaths'], c=df['aged65Older'], cmap='Blues', label='aged65Older')
plt.colorbar(label='aged65Older')
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.title('Total Deaths vs. age65Older')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

# Scatter plot for 'aged70Older' on the right side
plt.subplot(1, 2, 2)
plt.scatter(df['Date'], df['totalDeaths'], c=df['aged70Older'], cmap='Reds', label='aged70Older', marker='x')
plt.colorbar(label='aged70Older')
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.title('Total Deaths vs. age70Older')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

plt.tight_layout()  # Ensures that the subplots don't overlap
plt.show()

# %%
# Create a scatter plot with two subplots (one for 'age65Older' and one for 'age70Older')
plt.figure(figsize=(12, 6))

# Scatter plot for 'age65Older' on the left side
plt.subplot(1, 2, 1)
plt.scatter(df['Date'], df['newDeaths'], c=df['aged65Older'], cmap='Blues', label='aged65Older')
plt.colorbar(label='aged65Older')
plt.xlabel('Date')
plt.ylabel('New Deaths')
plt.title('New Deaths vs. age65Older')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

# Scatter plot for 'age70Older' on the right side
plt.subplot(1, 2, 2)
plt.scatter(df['Date'], df['newDeaths'], c=df['aged70Older'], cmap='Reds', label='aged70Older', marker='x')
plt.colorbar(label='aged70Older')
plt.xlabel('Date')
plt.ylabel('New Deaths')
plt.title('New Deaths vs. age70Older')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

plt.tight_layout()  # Ensures that the subplots don't overlap
plt.show()

# %%
# Assuming you have a DataFrame named 'df' with columns 'Date', 'totalDeaths', 'Male', and 'Female'
# Convert the 'Date' column to datetime if it's not already in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')

# Create a scatter plot with two subplots (one for 'Male' and one for 'Female')
plt.figure(figsize=(12, 6))

# Scatter plot for 'Male' on the left side
plt.subplot(1, 2, 1)
plt.scatter(df['Date'], df['totalDeaths'], c=df['maleSmokers'], cmap='Blues', label='Male')
plt.colorbar(label='Male Smokers')
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.title('Total Deaths vs. Male Smokers')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

# Scatter plot for 'Female' on the right side
plt.subplot(1, 2, 2)
plt.scatter(df['Date'], df['totalDeaths'], c=df['femaleSmokers'], cmap='Reds', label='Female', marker='x')
plt.colorbar(label='Female Smokers')
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.title('Total Deaths vs. Female Smokers')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.grid(True)

plt.tight_layout()  # Ensures that the subplots don't overlap
plt.show()

# %%
## Plot Smoking vs Total Cases and Total Death

# %%
## Plot Gender vs Total Cases and Total Death

# %%
# Create subplots for the line plots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Line plot for 'totalVaccinationsPerHundred'
ax1.plot(df['Date'], df['totalVaccinationsPerHundred'], label='Total Vaccinations per Hundred', color='blue')
ax1.set_xlabel('Date')
ax1.set_ylabel('Total Vaccinations per Hundred')
ax1.set_title('Total Vaccinations Over Time')
ax1.grid(True)
ax1.legend()

# Line plot for 'totalCases' and 'totalDeaths' on the same subplot
ax2.plot(df['Date'], df['totalCases'], label='Total Cases', color='green')
ax2.plot(df['Date'], df['totalDeaths'], label='Total Deaths', color='red')
ax2.set_xlabel('Date')
ax2.set_ylabel('Total Cases and Total Deaths')
ax2.set_title('Total Cases and Total Deaths Over Time')
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
# Assuming you have a DataFrame named 'df' with the relevant columns

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['totalCasesPerMillion'], df['peopleFullyVaccinatedPerHundred'], alpha=0.7)
plt.xlabel('Total Cases per Million')
plt.ylabel('People Fully Vaccinated per Hundred')
plt.title('Total Cases per Million vs People Fully Vaccinated per Hundred')
plt.grid(True)

plt.show()

# %%
# Assuming you have a DataFrame named 'df' with the relevant columns
# Convert the 'Date' column to datetime if it's not already in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')



# Create a scatter plot over time
plt.figure(figsize=(12, 6))

# Plot 'totalCasesPerMillion' over time
plt.plot(df['Date'], df['totalCasesPerMillion'], label='Total Cases per Million', marker='o', linestyle='-')

# Plot 'peopleFullyVaccinatedPerHundred' over time
plt.plot(df['Date'], df['peopleFullyVaccinatedPerHundred'], label='People Fully Vaccinated per Hundred', marker='x', linestyle='-')

plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Total Cases per Million vs People Fully Vaccinated per Hundred Over Time')
plt.legend()
plt.grid(True)

plt.show()
